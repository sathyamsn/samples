# %% [markdown]
# <a href="https://colab.research.google.com/github/sathyamsn/samples/blob/master/bees_ant_classifier_mobilenet_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from torchvision import models
import torch

dir(models)
# Out:
# ['AlexNet',
#  'DenseNet',
#  'GoogLeNet',
#  'GoogLeNetOutputs',
#  'Inception3',
#  'InceptionOutputs',
#  'MNASNet',
#  'MobileNetV2',
#  'ResNet',
#  'ShuffleNetV2',
#  'SqueezeNet',
#  'VGG',
#  '_GoogLeNetOutputs',
#  '_InceptionOutputs',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_utils',
#  'alexnet',
#  'densenet',
#  'densenet121',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'detection',
#  'googlenet',
#  'inception',
#  'inception_v3',
#  'mnasnet',
#  'mnasnet0_5',
#  'mnasnet0_75',
#  'mnasnet1_0',
#  'mnasnet1_3',
#  'mobilenet',
#  'mobilenet_v2',
#  'quantization',
#  'resnet',
#  'resnet101',
#  'resnet152',
#  'resnet18',
#  'resnet34',
#  'resnet50',
#  'resnext101_32x8d',
#  'resnext50_32x4d',
#  'segmentation',
#  'shufflenet_v2_x0_5',
#  'shufflenet_v2_x1_0',
#  'shufflenet_v2_x1_5',
#  'shufflenet_v2_x2_0',
#  'shufflenetv2',
#  'squeezenet',
#  'squeezenet1_0',
#  'squeezenet1_1',
#  'utils',
#  'vgg',
#  'vgg11',
#  'vgg11_bn',
#  'vgg13',
#  'vgg13_bn',
#  'vgg16',
#  'vgg16_bn',
#  'vgg19',
#  'vgg19_bn',
#  'video',
#  'wide_resnet101_2',
#  'wide_resnet50_2']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip ./data/hymenoptera_data.zip

# %%
# Standard library
import copy
import glob
import multiprocessing
import os
import time
import zipfile

# Pytorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms

# Related third party
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from PIL import Image
from skimage import io, transform
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm

# %%
input_size = 224
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

# Number of classes in the dataset
num_classes = 2 # bees, ant

# Batch size for training (change depending on how much memory you have)
batch_size = 16

# Number of epochs to train for
num_epochs = 2

# Flag for feature extracting. When False, we finetune the whole model,
#   when True we only update the reshaped layer params
feature_extract = True

# Switch to perform multi-process data loading
num_workers = multiprocessing.cpu_count()

# %% [markdown]
# Create training and validation datasets

# %%
import torch
from torchvision import transforms, datasets

# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(224),
        transforms.RandomCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = './hymenoptera_data'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size,
                                              shuffle=True, num_workers=num_workers)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
print('class_names : ', class_names)
print('dataset_sizes : ', dataset_sizes)

# %% [markdown]
# Visualize a few images

# %%
import torchvision

def imshow(inp, title=None, ax=None, figsize=(5, 5)):
  """Imshow for Tensor."""
  inp = inp.numpy().transpose((1, 2, 0))
  mean = np.array([0.485, 0.456, 0.406])
  std = np.array([0.229, 0.224, 0.225])
  inp = std * inp + mean
  inp = np.clip(inp, 0, 1)
  if ax is None:
    fig, ax = plt.subplots(1, figsize=figsize)
  ax.imshow(inp)
  ax.set_xticks([])
  ax.set_yticks([])
  if title is not None:
    ax.set_title(title)

# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs, nrow=4)

fig, ax = plt.subplots(1, figsize=(10, 10))
imshow(out, title=[class_names[x] for x in classes], ax=ax)

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25):
    since = time.time()

    history = {'accuracy': [],
               'val_accuracy': [],
               'loss': [],
               'val_loss': []}

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in tqdm(dataloaders[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

            if phase == 'train':
                history['accuracy'].append(epoch_acc.item())
                history['loss'].append(epoch_loss)
            else:
                history['val_accuracy'].append(epoch_acc.item())
                history['val_loss'].append(epoch_loss) 

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, history

# %%
train_list = image_datasets['train']
val_list = image_datasets['val']

# %%
print(len(train_list))
print(len(val_list))
# Out:
# 244
# 153

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(input_size, scale=(0.5, 1.0)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ])
}

# %%
model_ft = models.mobilenet_v2(pretrained=True)
#model_ft.classifier[1] = nn.Linear(4096, num_classes)
print(model_ft.classifier)
# Out:
# Sequential(
#   (0): Dropout(p=0.2, inplace=False)
#   (1): Linear(in_features=1280, out_features=1000, bias=True)
# )

# %%
model_ft.classifier[1] = torch.nn.Linear(in_features=model_ft.classifier[1].in_features, out_features=2)
print(model_ft.classifier)
# Out:
# Sequential(
#   (0): Dropout(p=0.2, inplace=False)
#   (1): Linear(in_features=1280, out_features=2, bias=True)
# )

# %%
# Send the model to GPU
model_ft = model_ft.to(device)

# Gather the parameters to be optimized/updated in this run. If we are
#  finetuning we will be updating all parameters. However, if we are
#  doing feature extract method, we will only update the parameters
#  that we have just initialized, i.e. the parameters with requires_grad
#  is True.
params_to_update = model_ft.parameters()
print("Params to learn:")
if feature_extract:
    params_to_update = []
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)
else:
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            print("\t",name)

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(params_to_update, lr=0.001, momentum=0.9)
# Out:
# Params to learn:
# 	 features.0.0.weight
# 	 features.0.1.weight
# 	 features.0.1.bias
# 	 features.1.conv.0.0.weight
# 	 features.1.conv.0.1.weight
# 	 features.1.conv.0.1.bias
# 	 features.1.conv.1.weight
# 	 features.1.conv.2.weight
# 	 features.1.conv.2.bias
# 	 features.2.conv.0.0.weight
# 	 features.2.conv.0.1.weight
# 	 features.2.conv.0.1.bias
# 	 features.2.conv.1.0.weight
# 	 features.2.conv.1.1.weight
# 	 features.2.conv.1.1.bias
# 	 features.2.conv.2.weight
# 	 features.2.conv.3.weight
# 	 features.2.conv.3.bias
# 	 features.3.conv.0.0.weight
# 	 features.3.conv.0.1.weight
# 	 features.3.conv.0.1.bias
# 	 features.3.conv.1.0.weight
# 	 features.3.conv.1.1.weight
# 	 features.3.conv.1.1.bias
# 	 features.3.conv.2.weight
# 	 features.3.conv.3.weight
# 	 features.3.conv.3.bias
# 	 features.4.conv.0.0.weight
# 	 features.4.conv.0.1.weight
# 	 features.4.conv.0.1.bias
# 	 features.4.conv.1.0.weight
# 	 features.4.conv.1.1.weight
# 	 features.4.conv.1.1.bias
# 	 features.4.conv.2.weight
# 	 features.4.conv.3.weight
# 	 features.4.conv.3.bias
# 	 features.5.conv.0.0.weight
# 	 features.5.conv.0.1.weight
# 	 features.5.conv.0.1.bias
# 	 features.5.conv.1.0.weight
# 	 features.5.conv.1.1.weight
# 	 features.5.conv.1.1.bias
# 	 features.5.conv.2.weight
# 	 features.5.conv.3.weight
# 	 features.5.conv.3.bias
# 	 features.6.conv.0.0.weight
# 	 features.6.conv.0.1.weight
# 	 features.6.conv.0.1.bias
# 	 features.6.conv.1.0.weight
# 	 features.6.conv.1.1.weight
# 	 features.6.conv.1.1.bias
# 	 features.6.conv.2.weight
# 	 features.6.conv.3.weight
# 	 features.6.conv.3.bias
# 	 features.7.conv.0.0.weight
# 	 features.7.conv.0.1.weight
# 	 features.7.conv.0.1.bias
# 	 features.7.conv.1.0.weight
# 	 features.7.conv.1.1.weight
# 	 features.7.conv.1.1.bias
# 	 features.7.conv.2.weight
# 	 features.7.conv.3.weight
# 	 features.7.conv.3.bias
# 	 features.8.conv.0.0.weight
# 	 features.8.conv.0.1.weight
# 	 features.8.conv.0.1.bias
# 	 features.8.conv.1.0.weight
# 	 features.8.conv.1.1.weight
# 	 features.8.conv.1.1.bias
# 	 features.8.conv.2.weight
# 	 features.8.conv.3.weight
# 	 features.8.conv.3.bias
# 	 features.9.conv.0.0.weight
# 	 features.9.conv.0.1.weight
# 	 features.9.conv.0.1.bias
# 	 features.9.conv.1.0.weight
# 	 features.9.conv.1.1.weight
# 	 features.9.conv.1.1.bias
# 	 features.9.conv.2.weight
# 	 features.9.conv.3.weight
# 	 features.9.conv.3.bias
# 	 features.10.conv.0.0.weight
# 	 features.10.conv.0.1.weight
# 	 features.10.conv.0.1.bias
# 	 features.10.conv.1.0.weight
# 	 features.10.conv.1.1.weight
# 	 features.10.conv.1.1.bias
# 	 features.10.conv.2.weight
# 	 features.10.conv.3.weight
# 	 features.10.conv.3.bias
# 	 features.11.conv.0.0.weight
# 	 features.11.conv.0.1.weight
# 	 features.11.conv.0.1.bias
# 	 features.11.conv.1.0.weight
# 	 features.11.conv.1.1.weight
# 	 features.11.conv.1.1.bias
# 	 features.11.conv.2.weight
# 	 features.11.conv.3.weight
# 	 features.11.conv.3.bias
# 	 features.12.conv.0.0.weight
# 	 features.12.conv.0.1.weight
# 	 features.12.conv.0.1.bias
# 	 features.12.conv.1.0.weight
# 	 features.12.conv.1.1.weight
# 	 features.12.conv.1.1.bias
# 	 features.12.conv.2.weight
# 	 features.12.conv.3.weight
# 	 features.12.conv.3.bias
# 	 features.13.conv.0.0.weight
# 	 features.13.conv.0.1.weight
# 	 features.13.conv.0.1.bias
# 	 features.13.conv.1.0.weight
# 	 features.13.conv.1.1.weight
# 	 features.13.conv.1.1.bias
# 	 features.13.conv.2.weight
# 	 features.13.conv.3.weight
# 	 features.13.conv.3.bias
# 	 features.14.conv.0.0.weight
# 	 features.14.conv.0.1.weight
# 	 features.14.conv.0.1.bias
# 	 features.14.conv.1.0.weight
# 	 features.14.conv.1.1.weight
# 	 features.14.conv.1.1.bias
# 	 features.14.conv.2.weight
# 	 features.14.conv.3.weight
# 	 features.14.conv.3.bias
# 	 features.15.conv.0.0.weight
# 	 features.15.conv.0.1.weight
# 	 features.15.conv.0.1.bias
# 	 features.15.conv.1.0.weight
# 	 features.15.conv.1.1.weight
# 	 features.15.conv.1.1.bias
# 	 features.15.conv.2.weight
# 	 features.15.conv.3.weight
# 	 features.15.conv.3.bias
# 	 features.16.conv.0.0.weight
# 	 features.16.conv.0.1.weight
# 	 features.16.conv.0.1.bias
# 	 features.16.conv.1.0.weight
# 	 features.16.conv.1.1.weight
# 	 features.16.conv.1.1.bias
# 	 features.16.conv.2.weight
# 	 features.16.conv.3.weight
# 	 features.16.conv.3.bias
# 	 features.17.conv.0.0.weight
# 	 features.17.conv.0.1.weight
# 	 features.17.conv.0.1.bias
# 	 features.17.conv.1.0.weight
# 	 features.17.conv.1.1.weight
# 	 features.17.conv.1.1.bias
# 	 features.17.conv.2.weight
# 	 features.17.conv.3.weight
# 	 features.17.conv.3.bias
# 	 features.18.0.weight
# 	 features.18.1.weight
# 	 features.18.1.bias
# 	 classifier.1.weight
# 	 classifier.1.bias

# %%
# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Train and evaluate
model_ft, hist = train_model(model_ft, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/1
# ----------
# HBox(children=(FloatProgress(value=0.0, max=16.0), HTML(value='')))
# train Loss: 0.5232 Acc: 0.7705
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# val Loss: 0.2790 Acc: 0.9085
#
# Epoch 1/1
# ----------
# HBox(children=(FloatProgress(value=0.0, max=16.0), HTML(value='')))
# train Loss: 0.2513 Acc: 0.9057
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# val Loss: 0.1860 Acc: 0.9216
#
# Training complete in 2m 4s
# Best val Acc: 0.921569

# %%
#Change path with yours
# !mkdir models
torch.save(model_ft.state_dict(), './models/bees_ant_model_ft_mnv2.pth')
torch.save(model_ft.state_dict(), './drive/My Drive/Data Set/models/bees_ant_model_ft_mnv2.pth')

# %% [markdown]
# Visualize training results

# %%
acc = hist['accuracy']
val_acc = hist['val_accuracy']
loss = hist['loss']
val_loss = hist['val_loss']
epochs_range = range(num_epochs)

plt.figure(figsize=(24, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#Change path with yours
path = './models/bees_ant_model_ft_mnv2.pth'

model = model_ft  

model.load_state_dict(torch.load(path))
# Out:
# <All keys matched successfully>

# %% [markdown]
# Predict

# %%
# train data file looks './train/dog.10435.jpg'
# test data file looks './test/10435.jpg'
def extract_class_from(path):
    file = path.split('/')[-1]
    return file.split('.')[0]

test_dir = './hymenoptera_data/val/bees/'
test_list = glob.glob(os.path.join(test_dir, '*.jpg'))
test_data_transform = data_transforms['val']

ids = []
labels = []
print (test_list)
with torch.no_grad():
    for test_path in tqdm(test_list):
        img = Image.open(test_path)
        img = test_data_transform(img)
        img = img.unsqueeze(0)
        img = img.to(device)

        model_ft.eval()
        outputs = model_ft(img)
        preds = F.softmax(outputs, dim=1)[:, 1].tolist()

        test_id = extract_class_from(test_path)
        ids.append((test_id))
        labels.append(preds[0])
# Out:
# ['./hymenoptera_data/val/bees/2501530886_e20952b97d.jpg', './hymenoptera_data/val/bees/144098310_a4176fd54d.jpg', './hymenoptera_data/val/bees/576452297_897023f002.jpg', './hymenoptera_data/val/bees/456097971_860949c4fc.jpg', './hymenoptera_data/val/bees/2782079948_8d4e94a826.jpg', './hymenoptera_data/val/bees/1297972485_33266a18d9.jpg', './hymenoptera_data/val/bees/1181173278_23c36fac71.jpg', './hymenoptera_data/val/bees/6a00d8341c630a53ef00e553d0beb18834-800wi.jpg', './hymenoptera_data/val/bees/2173503984_9c6aaaa7e2.jpg', './hymenoptera_data/val/bees/1486120850_490388f84b.jpg', './hymenoptera_data/val/bees/152789693_220b003452.jpg', './hymenoptera_data/val/bees/1519368889_4270261ee3.jpg', './hymenoptera_data/val/bees/590318879_68cf112861.jpg', './hymenoptera_data/val/bees/2709775832_85b4b50a57.jpg', './hymenoptera_data/val/bees/759745145_e8bc776ec8.jpg', './hymenoptera_data/val/bees/44105569_16720a960c.jpg', './hymenoptera_data/val/bees/2685605303_9eed79d59d.jpg', './hymenoptera_data/val/bees/2478216347_535c8fe6d7.jpg', './hymenoptera_data/val/bees/149973093_da3c446268.jpg', './hymenoptera_data/val/bees/224841383_d050f5f510.jpg', './hymenoptera_data/val/bees/2407809945_fb525ef54d.jpg', './hymenoptera_data/val/bees/238161922_55fa9a76ae.jpg', './hymenoptera_data/val/bees/220376539_20567395d8.jpg', './hymenoptera_data/val/bees/2841437312_789699c740.jpg', './hymenoptera_data/val/bees/603711658_4c8cd2201e.jpg', './hymenoptera_data/val/bees/2457841282_7867f16639.jpg', './hymenoptera_data/val/bees/2321144482_f3785ba7b2.jpg', './hymenoptera_data/val/bees/1032546534_06907fe3b3.jpg', './hymenoptera_data/val/bees/3077452620_548c79fda0.jpg', './hymenoptera_data/val/bees/400262091_701c00031c.jpg', './hymenoptera_data/val/bees/65038344_52a45d090d.jpg', './hymenoptera_data/val/bees/72100438_73de9f17af.jpg', './hymenoptera_data/val/bees/2506114833_90a41c5267.jpg', './hymenoptera_data/val/bees/2883093452_7e3a1eb53f.jpg', './hymenoptera_data/val/bees/2809496124_5f25b5946a.jpg', './hymenoptera_data/val/bees/215512424_687e1e0821.jpg', './hymenoptera_data/val/bees/485743562_d8cc6b8f73.jpg', './hymenoptera_data/val/bees/2741763055_9a7bb00802.jpg', './hymenoptera_data/val/bees/348291597_ee836fbb1a.jpg', './hymenoptera_data/val/bees/2525379273_dcb26a516d.jpg', './hymenoptera_data/val/bees/372228424_16da1f8884.jpg', './hymenoptera_data/val/bees/1799729694_0c40101071.jpg', './hymenoptera_data/val/bees/2668391343_45e272cd07.jpg', './hymenoptera_data/val/bees/177677657_a38c97e572.jpg', './hymenoptera_data/val/bees/464594019_1b24a28bb1.jpg', './hymenoptera_data/val/bees/2751836205_6f7b5eff30.jpg', './hymenoptera_data/val/bees/abeja.jpg', './hymenoptera_data/val/bees/603709866_a97c7cfc72.jpg', './hymenoptera_data/val/bees/26589803_5ba7000313.jpg', './hymenoptera_data/val/bees/2415414155_1916f03b42.jpg', './hymenoptera_data/val/bees/2509402554_31821cb0b6.jpg', './hymenoptera_data/val/bees/151594775_ee7dc17b60.jpg', './hymenoptera_data/val/bees/181171681_c5a1a82ded.jpg', './hymenoptera_data/val/bees/151603988_2c6f7d14c7.jpg', './hymenoptera_data/val/bees/2104135106_a65eede1de.jpg', './hymenoptera_data/val/bees/2815838190_0a9889d995.jpg', './hymenoptera_data/val/bees/936182217_c4caa5222d.jpg', './hymenoptera_data/val/bees/350436573_41f4ecb6c8.jpg', './hymenoptera_data/val/bees/187130242_4593a4c610.jpg', './hymenoptera_data/val/bees/416144384_961c326481.jpg', './hymenoptera_data/val/bees/2470492902_3572c90f75.jpg', './hymenoptera_data/val/bees/353266603_d3eac7e9a0.jpg', './hymenoptera_data/val/bees/59798110_2b6a3c8031.jpg', './hymenoptera_data/val/bees/290082189_f66cb80bfc.jpg', './hymenoptera_data/val/bees/2086294791_6f3789d8a6.jpg', './hymenoptera_data/val/bees/540976476_844950623f.jpg', './hymenoptera_data/val/bees/2745389517_250a397f31.jpg', './hymenoptera_data/val/bees/2444778727_4b781ac424.jpg', './hymenoptera_data/val/bees/203868383_0fcbb48278.jpg', './hymenoptera_data/val/bees/1355974687_1341c1face.jpg', './hymenoptera_data/val/bees/2670536155_c170f4 ...
# HBox(children=(FloatProgress(value=0.0, max=83.0), HTML(value='')))

# %% [markdown]
# **Check Prediction**

# %%
template = '"{}" with {:.2%} confidence'
def pred_result_message(pred):
    if pred > 0.7:
        return template.format('bees', pred)
    else:
        return template.format('ants', 1 - pred)

fig, axes = plt.subplots(nrows=4,
                         ncols=3,
                         figsize=(15, 10))
for img_path, label, ax in zip(test_list, labels, axes.ravel()):
    ax.set_title(pred_result_message(label))
    ax.imshow(Image.open(img_path))

# %% [markdown]
# ## also check https://colab.research.google.com/github/pytorch/tutorials/blob/gh-pages/_downloads/finetuning_torchvision_models_tutorial.ipynb?authuser=1
